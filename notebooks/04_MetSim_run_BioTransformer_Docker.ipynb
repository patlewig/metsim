# %% [markdown]
# # Generation of predictions using BioTransformer¶
#
#     Original functions Created by: Louis Groff
#     PIs: Imran Shah and Grace Patlewicz (GP)
#     Last modified by GP: 6 April 2024
#     Changes made: Example added using a Docker image.

# %% [markdown]
# Using the Dockerfile is supplied in the main directory of the repo, build a Docker image. Assuming the image is called "java", start the container running using the following command:
#
#  `docker run --user root  -p 9999:8888 -e CHOWN_HOME=yes -e CHOWN_HOME_OPTS='-R' -e jupyter_enable_lab=yes -v $(pwd):/home/jovyan/work -v ~/Documents/python/metsim/notebooks/test:/mybio java`
#
# Make sure the associated functions are associated with the right paths to point to the relevant location of the JAR file and where temp files are to be located.

# %%
import os
import subprocess
import numpy as np
import pandas as pd
import urllib.request, urllib.parse, json
import time
import tempfile
from rdkit import Chem
import datetime
#import multiprocess as mp
from itertools import compress
import pprint




def metsim_metadata_full(metsim_out = [], fnam = None, metsim_cache = None):
    
    if len(metsim_out) > 0:
        if metsim_cache != None:
            #Supplement metadata via serial HCD query through individual input chemicals, precursors, successors/metabolites for a full metsim dataset
            for i in range(len(metsim_out)): # i = number of input chemicals
                if metsim_out[i]['input']['inchikey'] != None:
                        continue
                if metsim_out[i]['input']['smiles'] not in [cache_item['smiles'] for cache_item in metsim_cache]:
                    metsim_out[i]['input'] = metsim_hcd_out(smiles = metsim_out[i]['input']['smiles'],
                                                            casrn = metsim_out[i]['input']['casrn'],
                                                            dtxsid = metsim_out[i]['input']['dtxsid'],
                                                            chem_name = metsim_out[i]['input']['chem_name'])
                    metsim_cache.append(metsim_out[i]['input'])
                    print('Input query added to metadata cache...')
                else:
                    print('Input SMILES found in cached results. Inserting into dictionary...')
                    metsim_out[i]['input'] = metsim_cache[[idx for idx in range(len(metsim_cache)) if metsim_cache[idx]['smiles'] == metsim_out[i]['input']['smiles']][0]]
                for j in range(len(metsim_out[i]['output'])): # j = number of unique precursors
                    if 'likelihood' in list(metsim_out[i]['output'][j]['precursor'].keys()):
                        if metsim_out[i]['output'][j]['precursor']['smiles'] not in [cache_item['smiles'] for cache_item in metsim_cache]:
                            metsim_out[i]['output'][j]['precursor'] = metsim_hcd_out(smiles = metsim_out[i]['output'][j]['precursor']['smiles'],
                                                                                     casrn = metsim_out[i]['output'][j]['precursor']['casrn'],
                                                                                     dtxsid = metsim_out[i]['output'][j]['precursor']['dtxsid'],
                                                                                     chem_name = metsim_out[i]['output'][j]['precursor']['chem_name'],
                                                                                     likely = metsim_out[i]['output'][j]['precursor']['likelihood'])
                            metsim_cache.append(metsim_out[i]['output'][j]['precursor'])
                            print('Precursor query added to metadata cache...')
                        else:
                            print('Precursor SMILES found in cached results. Inserting into dictionary...')
                            metsim_out[i]['output'][j]['precursor'] = metsim_cache[[idx for idx in range(len(metsim_cache)) if metsim_cache[idx]['smiles'] == metsim_out[i]['output'][j]['precursor']['smiles']][0]]
                    else:
                        if metsim_out[i]['output'][j]['precursor']['smiles'] not in [cache_item['smiles'] for cache_item in metsim_cache]:
                            metsim_out[i]['output'][j]['precursor'] = metsim_hcd_out(smiles = metsim_out[i]['output'][j]['precursor']['smiles'],
                                                                                     casrn = metsim_out[i]['output'][j]['precursor']['casrn'],
                                                                                     dtxsid = metsim_out[i]['output'][j]['precursor']['dtxsid'],
                                                                                     chem_name = metsim_out[i]['output'][j]['precursor']['chem_name'])
                            metsim_cache.append(metsim_out[i]['output'][j]['precursor'])
                            print('Precursor query added to metadata cache...')
                        else:
                            print('Precursor SMILES found in cached results. Inserting into dictionary...')
                            metsim_out[i]['output'][j]['precursor'] = metsim_cache[[idx for idx in range(len(metsim_cache)) if metsim_cache[idx]['smiles'] == metsim_out[i]['output'][j]['precursor']['smiles']][0]]
                    for k in range(len(metsim_out[i]['output'][j]['successors'])): # k = number of metabolites per precursor
                        if 'likelihood' in list(metsim_out[i]['output'][j]['successors'][k]['metabolite'].keys()):
                            if metsim_out[i]['output'][j]['successors'][k]['metabolite']['smiles'] not in [cache_item['smiles'] for cache_item in metsim_cache]:
                                metsim_out[i]['output'][j]['successors'][k]['metabolite'] = metsim_hcd_out(smiles = metsim_out[i]['output'][j]['successors'][k]['metabolite']['smiles'],
                                                                                                           casrn = metsim_out[i]['output'][j]['successors'][k]['metabolite']['casrn'],
                                                                                                           dtxsid = metsim_out[i]['output'][j]['successors'][k]['metabolite']['dtxsid'],
                                                                                                           chem_name = metsim_out[i]['output'][j]['successors'][k]['metabolite']['chem_name'],
                                                                                                           likely = metsim_out[i]['output'][j]['successors'][k]['metabolite']['likelihood'])
                                metsim_cache.append(metsim_out[i]['output'][j]['successors'][k]['metabolite'])
                                print('Successor metabolite query added to metadata cache...')
                            else:
                                print('Successor metabolite SMILES found in cached results. Inserting into dictionary...')
                                metsim_out[i]['output'][j]['successors'][k]['metabolite'] = metsim_cache[[idx for idx in range(len(metsim_cache)) if metsim_cache[idx]['smiles'] == metsim_out[i]['output'][j]['successors'][k]['metabolite']['smiles']][0]] 
                        else:
                            if metsim_out[i]['output'][j]['successors'][k]['metabolite']['smiles'] not in [cache_item['smiles'] for cache_item in metsim_cache]:
                                metsim_out[i]['output'][j]['successors'][k]['metabolite'] = metsim_hcd_out(smiles = metsim_out[i]['output'][j]['successors'][k]['metabolite']['smiles'],
                                                                                                           casrn = metsim_out[i]['output'][j]['successors'][k]['metabolite']['casrn'],
                                                                                                           dtxsid = metsim_out[i]['output'][j]['successors'][k]['metabolite']['dtxsid'],
                                                                                                           chem_name = metsim_out[i]['output'][j]['successors'][k]['metabolite']['chem_name'])
                                metsim_cache.append(metsim_out[i]['output'][j]['successors'][k]['metabolite'])
                                print('Successor metabolite query added to metadata cache...')
                            else:
                                print('Successor metabolite SMILES found in cached results. Inserting into dictionary...')
                                metsim_out[i]['output'][j]['successors'][k]['metabolite'] = metsim_cache[[idx for idx in range(len(metsim_cache)) if metsim_cache[idx]['smiles'] == metsim_out[i]['output'][j]['successors'][k]['metabolite']['smiles']][0]] 
                        print('input: '+str(i+1)+'/'+str(len(metsim_out))+' precursor: '+str(j+1)+'/'+str(len(metsim_out[i]['output']))+' metabolite: '+str(k+1)+'/'+str(len(metsim_out[i]['output'][j]['successors'])))
                if fnam != None:
                    json.dump(metsim_out, open(fnam,'w'))
        else:
            return metsim_metadata_full(metsim_out = metsim_out, fnam = fnam, metsim_cache = [])
    else:
        raise('Please supply a metsim dataset (list of dictionaries)')
    # print(metsim_out)
    return metsim_out    
    
#for generational tracking of output:
def recursive_gen_list(input_df = None,
                       parent_list = [],
                       successor_list = None,
                       out_list = [],
                       gen = 1):
    
    """
    Takes input dataframe derived from BioTransformer output CSV file for a given parent chemical, and recursively searches through the output Metabolite IDs 
    and Precursor IDs in the dataframe to correlate precursor-metabolite relationships across metabolic generations. Outputs a list of generationally-tracked 
    metabolites from the parent chemical and its precursors.
    
    inputs:
    input_df (dataframe, required): input dataframe derived from pandas read_csv of filename output from BioTransformer (btrans_metsim_subprocess output tuple, index 2 is CSV output filename)
    successor_list (list, optional): Metabolite ID column values from the parent BioTransformer output CSV
    parent_list (list, optional): Empty by default, previous generation's successor_list becomes the parent_list in later recursions until recursion is complete (i.e., empty successor_list)
    output:
    out_list (list): list of precursor-successor relationships for the parent chemical of interest in metsim hierarchical format.
    """
    
    
    
    if type(input_df) == 'NoneType':
        raise('Please include BioTransformer output csv dataframe as input_df.')
    successor_dict = {}
    for i in parent_list.index:
        if pd.isna(parent_list[i]):
            successor_df = input_df.loc[pd.isna(input_df['Precursor ID']),:]
            successor_list = successor_df['Metabolite ID']
            print(str(len(successor_list))+' Successors found for parent chemical')
        else:
            successor_df = input_df.loc[input_df['Precursor ID'] == parent_list[i],:]
            successor_list = successor_df['Metabolite ID']
        if len(successor_list) > 0:

            successor_dict = {'precursor': {'smiles': successor_df['Precursor SMILES'].unique()[0],
                                        'inchikey': None,
                                        'casrn': None,
                                        'hcd_smiles': None,
                                        'dtxsid': None,
                                        'chem_name': None
                                       },
                          'successors': [{'enzyme': successor_df.loc[j,'Enzyme(s)'].split('\n'),
                                          'mechanism': successor_df.loc[j,'Reaction'],
                                          'generation': gen,
                                          'metabolite': {'smiles': successor_df.loc[j,'SMILES'],
                                                         'inchikey': None,
                                                         'casrn': None,
                                                         'hcd_smiles': None,
                                                         'dtxsid': None,
                                                         'chem_name': None
                                                        }
                                       } for j in successor_df.index]
                             }
            if pd.notna(parent_list[i]):
                print(str(len(successor_df))+' successors found for gen '+str(gen)+' precursor '+parent_list[i])
            if successor_dict['precursor']['smiles'] in [out_list[j]['precursor']['smiles'] for j in range(len(out_list))]:
                print('Precursor-successor relationship already recorded, skipping to next precursor.')
            else:
                out_list = out_list+[successor_dict]
                print('dict added to out_list for index '+str(i))
                #check for more generations:
                for k in successor_list.index:
                    print('starting recursion on successor index '+str(k))
                    out_list = recursive_gen_list(input_df = input_df,
                                                  parent_list = pd.Series(successor_list[k]),
                                                  successor_list = [],
                                                  out_list = out_list,
                                                  gen = gen+1)
                    print('recursion complete for successor index '+str(k))
            return out_list
        else:
            print('No successors for gen '+str(gen)+' precursor '+parent_list[i]+', moving to next gen 1 precursor.')
            gen = 1
            return out_list


# Function 3: BioTransformer 3.0 Human Phase I + Phase II Metsim.
def btrans_metsim_subprocess(btrans_dir = '/home/jovyan/mybio',
                             models = ['ecbased','cyp450','phaseII'],
                             cyp_mode = 1,
                             cycles = [1,2,1],
                             smiles = None,
                             casrn = None,
                             del_tmp = False,
                             dtxsid = None,
                             chem_name = None,
                             idx = None,
                             multi_proc = False):
    
    '''
    
    Simulates human metabolism using BioTransformer via "subprocess" package virtual command line interface and Java command line inputs. Produces CSV output files in a ".\\tmpfiles" folder 
    Default settings are those from the 2024 MetSim manuscript (4 generations, 1 cycle Enzyme-Commission Based mixed Phase I & Phase II/"ecbased" + 2 cycles Phase I/"cyp450" + 1 cycle of Phase II/"phaseII" models, respectively).
    
    input:
    btrans_dir (str, required): file path leading to the BioTransformer3.0Jar directory. Default is C:\BioTransformer3.0Jar
    models (list of str, optional): List of models in the sequence they will be run. Default is ['ecbased','cyp450','phaseII']
    cyp_mode (int, optional): "Cyp450" model execution mode. 1 uses CypReact as default engine (default), 2 uses CyProduct engine (prone to crashes as of June 2022), 3 is combined engine (CypReact+CyProduct engines)
    cycles (list of int, optional) List of integer number of metabolism cycles each model will execute in the order they are defined in "models" parameter. Default is [1,2,1] to indicate 1 cycle of "ecbased", 2 cycles of "cyp450", and 1 cycle of "phaseII"
    smiles (str, required): SMILES string corresponding to parent chemical. Default None
    casrn (str, optional): Chemical Abstracts Services Registry Number (CASRN), if known. Default None
    del_tmp (True/False, optional): Delete Tempfiles to free up storage after they are processed through recursive_gen_list. Default False
    dtxsid (str, optional): EPA Distributed Structure Searchable Toxicity Database (DSSTox) Substance Identifier (DSTXSID) for parent chemical, if known. Default None 
    chem_name (str, optional): Preferred chemical name of parent, if known. Default None
    idx (int, optional): Dummy index (default None). Only needed if feeding this function into a "multiprocess" function call to parallel process multiple parent chemicals with metsim_bt
    multi_proc (True/False, optional): If using multiprocessing to ensure that "idx" parameter gets stored in output tuple. Default False
    
    Output: 
    Tuple with dummy index (for parallel processing), Dictionary of precursor and successor SMILES, CASRN, DTXSID, InChIKey as supplemented by HCD (or RDKit for InChIKey), and filename (if del_tmp = False).

    '''
    
# Need to determine how to implement recursion with multiprocessing...
    
    #set up initial dictionary outputs:
    btrans_dict = {'datetime': str(datetime.datetime.now().strftime('%Y-%m-%d_%Hh%Mm%Ss')),
                   'software': 'BioTransformer',
                   'version': 3.0,
                   'params':{'depth': sum([cycles[i] if ('allHuman' != models[i]) and ('superbio' != models[i]) else 4 for i in range(len(cycles))]),
                             'organism': 'Human',
                             'site_of_metabolism': False,
                             'model': [str(cycles[i])+'x '+models[i] for i in range(len(models))]
                            }
                  }
    btrans_dict['input'] = {'smiles': smiles,
                            'inchikey': None,
                            'casrn': casrn,
                            'hcd_smiles': None,
                            'dtxsid': dtxsid,
                            'chem_name': chem_name
                           } 
    
    #change directory to BioTransformer directory
    if os.curdir != btrans_dir:
        os.chdir(btrans_dir)
    
   #Ensure appropriate output CSV file folder exists for temporary files:
    tmp_filepath ='/home/jovyan/work/bt_tmpfiles'
    if not os.path.exists(tmp_filepath):
        os.makedirs(tmp_filepath)
       
    if pd.notna(smiles): #check that we have a SMILES string input
        #Begin constructing BioTransformer input command string:
        btrans_cmd = 'java -jar BioTransformer3.0.jar -k pred ' #current version
        # btrans_cmd = 'java -jar BioTransformer-1.1.5.jar -k pred ' #2019 paper version
        # btrans_cmd = 'java -jar BioTransformer-1-0-6.jar -k pred ' #original version (Only uses single models!)
        #incorporate model parameters into command string:
        if len(models) == 1:
            btrans_model = '-b "'+models[0]+'" '
            if cycles[0] > 1:
                btrans_model = btrans_model+'-s '+str(cycles[0])
        else:
            btrans_model = '-q "'
            for i in range(len(models)):
                if i < len(models)-1:
                    btrans_model = btrans_model+models[i]+':'+str(cycles[i])+';'
                else:
                    btrans_model = btrans_model+models[i]+':'+str(cycles[i])+'" '
        btrans_cmd = btrans_cmd+btrans_model+' -cm '+str(cyp_mode)+' ' #specify cyp_mode with later versions of BioTransformer
        # btrans_cmd = btrans_cmd+btrans_model+' ' #no cyp_mode in input command for original 2019 relase of BioTransformer
        #create temporary file to store BioTransformer output:
        if dtxsid != None:
            print('Generating output tempfile for index '+str(idx)+', DTXSID: '+str(dtxsid)+'...')
            fnum, fnam = tempfile.mkstemp(dir = '/home/jovyan/work/bt_tmpfiles',
                                          prefix = 'btrans_out_'+dtxsid+'_',
                                          suffix = '.csv')
        else:
            try:
                print('Generating output tempfile for index '+str(idx)+', InChIKey: '+Chem.inchi.MolToInchiKey(Chem.MolFromSmiles(smiles))+'...')
                fnum, fnam = tempfile.mkstemp(dir = '/home/jovyan/work/bt_tmpfiles',
                                              prefix = 'btrans_out_'+Chem.inchi.MolToInchiKey(Chem.MolFromSmiles(smiles))+'_',
                                              suffix = '.csv')
            except:
                print('Generating output tempfile for index '+str(idx)+', SMILES: '+smiles+'...')
                fnum, fnam = tempfile.mkstemp(dir = '/home/jovyan/work/bt_tmpfiles',
                                          prefix = 'btrans_out_',
                                          suffix = '.csv')
        
        #Finish constructing input command using the tempfile name:
        fnam_split = fnam.split('/')
        btrans_fnam = tmp_filepath + '/' +fnam_split[-1]
        #insert input smiles string and output csv tempfile name:
        btrans_cmd = btrans_cmd + '-ismi "'+smiles+'" -ocsv "'+btrans_fnam+'"' #use Daylight SMILES input
        # btrans_cmd = btrans_cmd + '-isdf "'+smiles+'" -ocsv "'+btrans_fnam+'"'
        print(btrans_cmd)
        #Run BioTransformer with subprocess and the appropriate input command string:
        print('beginning metsim for index #'+str(idx)+'...')
        btrans_out = subprocess.run(btrans_cmd,
                                    shell=True,
                                    stdout=subprocess.PIPE) 
        
        #Preallocate data frame and read tempfile output if BioTransformer ran successfully:
        btrans_out_df = pd.DataFrame()
        if btrans_out.stderr == None:
            try:
                btrans_out_df = pd.read_csv(fnam)
            except:
                pass
        else:
            print('error, check stdout')
            print(btrans_out.stdout.decode())
            
        btrans_dict['output'] = []
        if multi_proc == False:
            #Process metabolism data (if it exists for the given smiles):
            if os.path.getsize(fnam) > 0:
                input_df = pd.read_csv(fnam)
                parent_list = input_df['Precursor ID']
                parent_list = parent_list.drop_duplicates()
                btrans_dict['output'] = recursive_gen_list(input_df = input_df,
                                                           parent_list = parent_list,
                                                           successor_list = [],
                                                           out_list = [],
                                                           gen = 1)
            else: #Valid SMILES given, no metabolites produced:
                print('No metabolites produced for index #'+str(i))
                btrans_dict['output'] = [{'precursor': btrans_dict['input'],
                                          'successors': [{'enzyme': [],
                                                          'mechanism': None,
                                                          'generation': None,
                                                          'metabolite': {'smiles': None,
                                                                         'inchikey': None,
                                                                         'casrn': None,
                                                                         'hcd_smiles': None,
                                                                         'dtxsid': None,
                                                                         'chem_name': None
                                                                        }
                                                        }]
                                        }]
        else:
            #Need to determine how to multiprocess recursion, until then, store input parameters and output structure.
            btrans_dict['output'] = [{'precursor': btrans_dict['input'],
                                      'successors': [{'enzyme': [],
                                                      'mechanism': None,
                                                      'generation': None,
                                                      'metabolite': {'smiles': None,
                                                                     'inchikey': None,
                                                                     'casrn': None,
                                                                     'hcd_smiles': None,
                                                                     'dtxsid': None,
                                                                     'chem_name': None
                                                                    }
                                                    }]
                                    }]
        #close temporary output file. Will delete if del_tempfile function input is set to True.
        os.close(fnum)
        if del_tmp == True:
            os.remove(fnam)
    else:
        print('No SMILES string provided for index #'+str(idx)+".")
        #This list returns if no metabolites are formed/BioTransformer fails.
        btrans_dict['output'] = [{'precursor': {'smiles': None,
                                                'inchikey': None,
                                                'casrn': None,
                                                'hcd_smiles': None,
                                                'dtxsid': None,
                                                'chem_name': None
                                               },
                                  'successors': [{'enzyme': [],
                                                  'mechanism': None,
                                                  'generation': None,
                                                  'metabolite': {'smiles': None,
                                                                 'inchikey': None,
                                                                 'casrn': None,
                                                                 'hcd_smiles': None,
                                                                 'dtxsid': None,
                                                                 'chem_name': None
                                                                }
                                                }]
                                }]
        btrans_dict['input'] = {'smiles': None,
                                'inchikey': None,
                                'casrn': None,
                                'hcd_smiles': None,
                                'dtxsid': None,
                                'chem_name': None
                               }
    print('MetSim complete for index '+str(idx)+'.')
    if del_tmp == False:
        #until figuring out how to implement recursive metabolite search with multiprocessing, return filename for separate analysis function.
        return (idx, btrans_dict, fnam)
    else:
        return (idx, btrans_dict, None)

# %% [markdown]
# ### Example for a single chemical, Ibuprofen

# %%
btrans_metsim_subprocess(smiles = 'CC(C)CC1=CC=C(C=C1)C(C)C(O)=O',dtxsid = 'DTXSID3047138')
# Out:
# Generating output tempfile for index None, DTXSID: DTXSID3047138...
# java -jar BioTransformer3.0.jar -k pred -q "ecbased:1;cyp450:2;phaseII:1"  -cm 1 -ismi "CC(C)CC1=CC=C(C=C1)C(C)C(O)=O" -ocsv "/home/jovyan/work/bt_tmpfiles/btrans_out_DTXSID3047138_ud0k9966.csv"
# beginning metsim for index #None...
# 3 Successors found for parent chemical
# dict added to out_list for index 0
# starting recursion on successor index 0
# 15 successors found for gen 2 precursor BTM00001
# dict added to out_list for index 0
# starting recursion on successor index 3
# 12 successors found for gen 3 precursor BTM00004
# dict added to out_list for index 0
# starting recursion on successor index 34
# 4 successors found for gen 4 precursor BTM00025
# dict added to out_list for index 0
# starting recursion on successor index 357
# No successors for gen 5 precursor BTM00175, moving to next gen 1 precursor.
# recursion complete for successor index 357
# starting recursion on successor index 358
# No successors for gen 5 precursor BTM00176, moving to next gen 1 precursor.
# recursion complete for successor index 358
# starting recursion on successor index 359
# No successors for gen 5 precursor BTM00177, moving to next gen 1 precursor.
# recursion complete for successor index 359
# starting recursion on successor index 360
# No successors for gen 5 precursor BTM00178, moving to next gen 1 precursor.
# recursion complete for successor index 360
# recursion complete for successor index 34
# starting recursion on successor index 35
# 4 successors found for gen 4 precursor BTM00026
# dict added to out_list for index 0
# starting recursion on successor index 361
# No successors for gen 5 precursor BTM00179, moving to next gen 1 precursor.
# recursion complete for successor index 361
# starting recursion on successor index 362
# No successors for gen 5 precursor BTM00179, moving to next gen 1 precursor.
# recursion complete for successor index 362
# starting recursion on successor index 363
# No successors for gen 5 precursor BTM00180, moving to next gen 1 precursor.
# recursion complete for successor index 363
# starting recursion on successor index 364
# No successors for gen 5 precursor BTM00181, moving to next gen 1 precursor.
# recursion complete for successor index 364
# recursion complete for successor index 35
# starting recursion on successor index 36
# 4 successors found for gen 4 precursor BTM00027
# dict added to out_list for index 0
# starting recursion on successor index 365
# No successors for gen 5 precursor BTM00182, moving to next gen 1 precursor.
# recursion complete for successor index 365
# starting recursion on successor index 366
# No successors for gen 5 precursor BTM00182, moving to next gen 1 precursor.
# recursion complete for successor index 366
# starting recursion on successor index 367
# No successors for gen 5 precursor BTM00183, moving to next gen 1 precursor.
# recursion complete for successor index 367
# starting recursion on successor index 368
# No successors for gen 5 precursor BTM00184, moving to next gen 1 precursor.
# recursion complete for successor index 368
# recursion complete for successor index 36
# starting recursion on successor index 37
# 4 successors found for gen 4 precursor BTM00028
# dict added to out_list for index 0
# starting recursion on successor index 369
# No successors for gen 5 precursor BTM00185, moving to next gen 1 precursor.
# recursion complete for successor index 369
# starting recursion on successor index 370
# No successors for gen 5 precursor BTM00186, moving to next gen 1 precursor.
# recursion complete for successor index 370
# starting recursion on successor index 371
# No successors for gen 5 precursor BTM00187, moving to next gen 1 precursor.
# recursion complete for successor index 371
# starting recursion on successor index 372
# No successors for gen 5 precursor BTM00188, moving to next gen 1 precursor.
# recursion complete for successor index 372
# recursion complete for successor index 37
# starting recursion on successor index 38
# 4 successors found for gen 4 precursor BTM00029
# dict added to out_list for index 0
# starting recursion on successor index 373
# No successors for gen 5 precursor BTM00189, moving to next gen 1 precursor.
# recursion complete for successor index 373
# starting recursion on successor index 374
# No successors for gen 5 precursor BTM00190, moving to next gen 1 precursor.
# recursion complete for successor index 374
# starting recursion on successor index 375
# No successors for gen 5 precursor BTM00191, moving to next gen 1 precursor.
# recursion complete for successor index 375
# starting recursion on successor index 376
# No successors for gen 5 precursor BTM00192, moving to next gen 1 precursor.
# recursion complete for successor index 376
# recursion complete for successor index 38
# starting recursion on successor index 39
# 2 successors found for gen 4 precursor BTM00030
# dict added to out_list for index 0
# starting recursion on successor index 377
# No successors for gen 5 precursor BTM00193, moving to next gen 1 precursor.
# recursion complete for successor index 377
# starting recursion on successor index 378
# No successors for gen 5 precursor BTM00194, moving to next gen 1 precursor.
# recursion complete for successor index 378
# recursion complete for successor index 39
# starting recursion on successor index 40
# 4 successors found for gen 4 precursor BTM00031
# dict added to out_list for index 0
# starting recursion on successor index 379
# No successors for gen 5 precursor BTM00195, moving to next gen 1 precursor.
# recursion complete for successor index 379
# starting recursion on successor index 380
# No successors for gen 5 precursor BTM00196, moving to next gen 1 precursor.
# recursion complete for successor index 380
# starting recursion on successor index 381
# No successors for gen 5 precursor BTM00197, moving to next gen 1 precursor.
# recursion complete for successor index 381
# starting recursion on successor index 382
# No successors for gen 5 precursor BTM00198, moving to next gen 1 precursor.
# recursion complete for successor index 382
# recursion complete for successor index 40
# starting recursion on successor index 41
# 4 successors found for gen 4 precursor BTM00025
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 41
# starting recursion on successor index 42
# 3 successors found for gen 4 precursor BTM00032
# dict added to out_list for index 0
# starting recursion on successor index 383
# No successors for gen 5 precursor BTM00199, moving to next gen 1 precursor.
# recursion complete for successor index 383
# starting recursion on successor index 384
# No successors for gen 5 precursor BTM00200, moving to next gen 1 precursor.
# recursion complete for successor index 384
# starting recursion on successor index 385
# No successors for gen 5 precursor BTM00201, moving to next gen 1 precursor.
# recursion complete for successor index 385
# recursion complete for successor index 42
# starting recursion on successor index 43
# 3 successors found for gen 4 precursor BTM00032
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 43
# starting recursion on successor index 312
# No successors for gen 4 precursor BTM00134, moving to next gen 1 precursor.
# recursion complete for successor index 312
# starting recursion on successor index 313
# No successors for gen 4 precursor BTM00135, moving to next gen 1 precursor.
# recursion complete for successor index 313
# recursion complete for successor index 3
# starting recursion on successor index 4
# 17 successors found for gen 3 precursor BTM00005
# dict added to out_list for index 0
# starting recursion on successor index 44
# 4 successors found for gen 4 precursor BTM00025
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 44
# starting recursion on successor index 45
# 1 successors found for gen 4 precursor BTM00033
# dict added to out_list for index 0
# starting recursion on successor index 386
# No successors for gen 5 precursor BTM00202, moving to next gen 1 precursor.
# recursion complete for successor index 386
# recursion complete for successor index 45
# starting recursion on successor index 46
# 4 successors found for gen 4 precursor BTM00025
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 46
# starting recursion on successor index 47
# 4 successors found for gen 4 precursor BTM00034
# dict added to out_list for index 0
# starting recursion on successor index 387
# No successors for gen 5 precursor BTM00203, moving to next gen 1 precursor.
# recursion complete for successor index 387
# starting recursion on successor index 388
# No successors for gen 5 precursor BTM00203, moving to next gen 1 precursor.
# recursion complete for successor index 388
# starting recursion on successor index 389
# No successors for gen 5 precursor BTM00204, moving to next gen 1 precursor.
# recursion complete for successor index 389
# starting recursion on successor index 390
# No successors for gen 5 precursor BTM00205, moving to next gen 1 precursor.
# recursion complete for successor index 390
# recursion complete for successor index 47
# starting recursion on successor index 48
# 4 successors found for gen 4 precursor BTM00035
# dict added to out_list for index 0
# starting recursion on successor index 391
# No successors for gen 5 precursor BTM00206, moving to next gen 1 precursor.
# recursion complete for successor index 391
# starting recursion on successor index 392
# No successors for gen 5 precursor BTM00206, moving to next gen 1 precursor.
# recursion complete for successor index 392
# starting recursion on successor index 393
# No successors for gen 5 precursor BTM00207, moving to next gen 1 precursor.
# recursion complete for successor index 393
# starting recursion on successor index 394
# No successors for gen 5 precursor BTM00208, moving to next gen 1 precursor.
# recursion complete for successor index 394
# recursion complete for successor index 48
# starting recursion on successor index 49
# 5 successors found for gen 4 precursor BTM00036
# dict added to out_list for index 0
# starting recursion on successor index 395
# No successors for gen 5 precursor BTM00209, moving to next gen 1 precursor.
# recursion complete for successor index 395
# starting recursion on successor index 396
# No successors for gen 5 precursor BTM00210, moving to next gen 1 precursor.
# recursion complete for successor index 396
# starting recursion on successor index 397
# No successors for gen 5 precursor BTM00211, moving to next gen 1 precursor.
# recursion complete for successor index 397
# starting recursion on successor index 398
# No successors for gen 5 precursor BTM00212, moving to next gen 1 precursor.
# recursion complete for successor index 398
# starting recursion on successor index 399
# No successors for gen 5 precursor BTM00213, moving to next gen 1 precursor.
# recursion complete for successor index 399
# recursion complete for successor index 49
# starting recursion on successor index 50
# 5 successors found for gen 4 precursor BTM00037
# dict added to out_list for index 0
# starting recursion on successor index 400
# No successors for gen 5 precursor BTM00214, moving to next gen 1 precursor.
# recursion complete for successor index 400
# starting recursion on successor index 401
# No successors for gen 5 precursor BTM00215, moving to next gen 1 precursor.
# recursion complete for successor index 401
# starting recursion on successor index 402
# No successors for gen 5 precursor BTM00216, moving to next gen 1 precursor.
# recursion complete for successor index 402
# starting recursion on successor index 403
# No successors for gen 5 precursor BTM00217, moving to next gen 1 precursor.
# recursion complete for successor index 403
# starting recursion on successor index 404
# No successors for gen 5 precursor BTM00218, moving to next gen 1 precursor.
# recursion complete for successor index 404
# recursion complete for successor index 50
# starting recursion on successor index 51
# 3 successors found for gen 4 precursor BTM00038
# dict added to out_list for index 0
# starting recursion on successor index 405
# No successors for gen 5 precursor BTM00219, moving to next gen 1 precursor.
# recursion complete for successor index 405
# starting recursion on successor index 406
# No successors for gen 5 precursor BTM00220, moving to next gen 1 precursor.
# recursion complete for successor index 406
# starting recursion on successor index 407
# No successors for gen 5 precursor BTM00221, moving to next gen 1 precursor.
# recursion complete for successor index 407
# recursion complete for successor index 51
# starting recursion on successor index 52
# 3 successors found for gen 4 precursor BTM00039
# dict added to out_list for index 0
# starting recursion on successor index 408
# No successors for gen 5 precursor BTM00222, moving to next gen 1 precursor.
# recursion complete for successor index 408
# starting recursion on successor index 409
# No successors for gen 5 precursor BTM00223, moving to next gen 1 precursor.
# recursion complete for successor index 409
# starting recursion on successor index 410
# No successors for gen 5 precursor BTM00224, moving to next gen 1 precursor.
# recursion complete for successor index 410
# recursion complete for successor index 52
# starting recursion on successor index 53
# 5 successors found for gen 4 precursor BTM00040
# dict added to out_list for index 0
# starting recursion on successor index 411
# No successors for gen 5 precursor BTM00225, moving to next gen 1 precursor.
# recursion complete for successor index 411
# starting recursion on successor index 412
# No successors for gen 5 precursor BTM00226, moving to next gen 1 precursor.
# recursion complete for successor index 412
# starting recursion on successor index 413
# No successors for gen 5 precursor BTM00227, moving to next gen 1 precursor.
# recursion complete for successor index 413
# starting recursion on successor index 414
# No successors for gen 5 precursor BTM00228, moving to next gen 1 precursor.
# recursion complete for successor index 414
# starting recursion on successor index 415
# No successors for gen 5 precursor BTM00229, moving to next gen 1 precursor.
# recursion complete for successor index 415
# recursion complete for successor index 53
# starting recursion on successor index 54
# 4 successors found for gen 4 precursor BTM00025
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 54
# starting recursion on successor index 55
# 4 successors found for gen 4 precursor BTM00041
# dict added to out_list for index 0
# starting recursion on successor index 416
# No successors for gen 5 precursor BTM00230, moving to next gen 1 precursor.
# recursion complete for successor index 416
# starting recursion on successor index 417
# No successors for gen 5 precursor BTM00231, moving to next gen 1 precursor.
# recursion complete for successor index 417
# starting recursion on successor index 418
# No successors for gen 5 precursor BTM00232, moving to next gen 1 precursor.
# recursion complete for successor index 418
# starting recursion on successor index 419
# No successors for gen 5 precursor BTM00233, moving to next gen 1 precursor.
# recursion complete for successor index 419
# recursion complete for successor index 55
# starting recursion on successor index 56
# 4 successors found for gen 4 precursor BTM00025
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 56
# starting recursion on successor index 57
# 4 successors found for gen 4 precursor BTM00041
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 57
# starting recursion on successor index 314
# No successors for gen 4 precursor BTM00136, moving to next gen 1 precursor.
# recursion complete for successor index 314
# starting recursion on successor index 315
# No successors for gen 4 precursor BTM00137, moving to next gen 1 precursor.
# recursion complete for successor index 315
# starting recursion on successor index 316
# No successors for gen 4 precursor BTM00138, moving to next gen 1 precursor.
# recursion complete for successor index 316
# recursion complete for successor index 4
# starting recursion on successor index 5
# 12 successors found for gen 3 precursor BTM00004
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 5
# starting recursion on successor index 6
# 21 successors found for gen 3 precursor BTM00006
# dict added to out_list for index 0
# starting recursion on successor index 58
# 4 successors found for gen 4 precursor BTM00026
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 58
# starting recursion on successor index 59
# 4 successors found for gen 4 precursor BTM00034
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 59
# starting recursion on successor index 60
# 4 successors found for gen 4 precursor BTM00026
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 60
# starting recursion on successor index 61
# 3 successors found for gen 4 precursor BTM00042
# dict added to out_list for index 0
# starting recursion on successor index 420
# No successors for gen 5 precursor BTM00234, moving to next gen 1 precursor.
# recursion complete for successor index 420
# starting recursion on successor index 421
# No successors for gen 5 precursor BTM00235, moving to next gen 1 precursor.
# recursion complete for successor index 421
# starting recursion on successor index 422
# No successors for gen 5 precursor BTM00236, moving to next gen 1 precursor.
# recursion complete for successor index 422
# recursion complete for successor index 61
# starting recursion on successor index 62
# 8 successors found for gen 4 precursor BTM00043
# dict added to out_list for index 0
# starting recursion on successor index 423
# No successors for gen 5 precursor BTM00237, moving to next gen 1 precursor.
# recursion complete for successor index 423
# starting recursion on successor index 424
# No successors for gen 5 precursor BTM00238, moving to next gen 1 precursor.
# recursion complete for successor index 424
# starting recursion on successor index 425
# No successors for gen 5 precursor BTM00237, moving to next gen 1 precursor.
# recursion complete for successor index 425
# starting recursion on successor index 426
# No successors for gen 5 precursor BTM00238, moving to next gen 1 precursor.
# recursion complete for successor index 426
# starting recursion on successor index 427
# No successors for gen 5 precursor BTM00239, moving to next gen 1 precursor.
# recursion complete for successor index 427
# starting recursion on successor index 428
# No successors for gen 5 precursor BTM00240, moving to next gen 1 precursor.
# recursion complete for successor index 428
# starting recursion on successor index 429
# No successors for gen 5 precursor BTM00241, moving to next gen 1 precursor.
# recursion complete for successor index 429
# starting recursion on successor index 430
# No successors for gen 5 precursor BTM00242, moving to next gen 1 precursor.
# recursion complete for successor index 430
# recursion complete for successor index 62
# starting recursion on successor index 63
# 3 successors found for gen 4 precursor BTM00042
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 63
# starting recursion on successor index 64
# 5 successors found for gen 4 precursor BTM00044
# dict added to out_list for index 0
# starting recursion on successor index 431
# No successors for gen 5 precursor BTM00243, moving to next gen 1 precursor.
# recursion complete for successor index 431
# starting recursion on successor index 432
# No successors for gen 5 precursor BTM00243, moving to next gen 1 precursor.
# recursion complete for successor index 432
# starting recursion on successor index 433
# No successors for gen 5 precursor BTM00244, moving to next gen 1 precursor.
# recursion complete for successor index 433
# starting recursion on successor index 434
# No successors for gen 5 precursor BTM00245, moving to next gen 1 precursor.
# recursion complete for successor index 434
# starting recursion on successor index 435
# No successors for gen 5 precursor BTM00246, moving to next gen 1 precursor.
# recursion complete for successor index 435
# recursion complete for successor index 64
# starting recursion on successor index 65
# 5 successors found for gen 4 precursor BTM00045
# dict added to out_list for index 0
# starting recursion on successor index 436
# No successors for gen 5 precursor BTM00247, moving to next gen 1 precursor.
# recursion complete for successor index 436
# starting recursion on successor index 437
# No successors for gen 5 precursor BTM00247, moving to next gen 1 precursor.
# recursion complete for successor index 437
# starting recursion on successor index 438
# No successors for gen 5 precursor BTM00248, moving to next gen 1 precursor.
# recursion complete for successor index 438
# starting recursion on successor index 439
# No successors for gen 5 precursor BTM00249, moving to next gen 1 precursor.
# recursion complete for successor index 439
# starting recursion on successor index 440
# No successors for gen 5 precursor BTM00250, moving to next gen 1 precursor.
# recursion complete for successor index 440
# recursion complete for successor index 65
# starting recursion on successor index 66
# 4 successors found for gen 4 precursor BTM00046
# dict added to out_list for index 0
# starting recursion on successor index 441
# No successors for gen 5 precursor BTM00251, moving to next gen 1 precursor.
# recursion complete for successor index 441
# starting recursion on successor index 442
# No successors for gen 5 precursor BTM00251, moving to next gen 1 precursor.
# recursion complete for successor index 442
# starting recursion on successor index 443
# No successors for gen 5 precursor BTM00252, moving to next gen 1 precursor.
# recursion complete for successor index 443
# starting recursion on successor index 444
# No successors for gen 5 precursor BTM00253, moving to next gen 1 precursor.
# recursion complete for successor index 444
# recursion complete for successor index 66
# starting recursion on successor index 67
# 4 successors found for gen 4 precursor BTM00047
# dict added to out_list for index 0
# starting recursion on successor index 445
# No successors for gen 5 precursor BTM00254, moving to next gen 1 precursor.
# recursion complete for successor index 445
# starting recursion on successor index 446
# No successors for gen 5 precursor BTM00254, moving to next gen 1 precursor.
# recursion complete for successor index 446
# starting recursion on successor index 447
# No successors for gen 5 precursor BTM00255, moving to next gen 1 precursor.
# recursion complete for successor index 447
# starting recursion on successor index 448
# No successors for gen 5 precursor BTM00256, moving to next gen 1 precursor.
# recursion complete for successor index 448
# recursion complete for successor index 67
# starting recursion on successor index 68
# 8 successors found for gen 4 precursor BTM00043
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 68
# starting recursion on successor index 69
# 3 successors found for gen 4 precursor BTM00048
# dict added to out_list for index 0
# starting recursion on successor index 449
# No successors for gen 5 precursor BTM00257, moving to next gen 1 precursor.
# recursion complete for successor index 449
# starting recursion on successor index 450
# No successors for gen 5 precursor BTM00258, moving to next gen 1 precursor.
# recursion complete for successor index 450
# starting recursion on successor index 451
# No successors for gen 5 precursor BTM00259, moving to next gen 1 precursor.
# recursion complete for successor index 451
# recursion complete for successor index 69
# starting recursion on successor index 70
# 4 successors found for gen 4 precursor BTM00026
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 70
# starting recursion on successor index 71
# 4 successors found for gen 4 precursor BTM00034
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 71
# starting recursion on successor index 72
# 4 successors found for gen 4 precursor BTM00049
# dict added to out_list for index 0
# starting recursion on successor index 452
# No successors for gen 5 precursor BTM00260, moving to next gen 1 precursor.
# recursion complete for successor index 452
# starting recursion on successor index 453
# No successors for gen 5 precursor BTM00260, moving to next gen 1 precursor.
# recursion complete for successor index 453
# starting recursion on successor index 454
# No successors for gen 5 precursor BTM00261, moving to next gen 1 precursor.
# recursion complete for successor index 454
# starting recursion on successor index 455
# No successors for gen 5 precursor BTM00262, moving to next gen 1 precursor.
# recursion complete for successor index 455
# recursion complete for successor index 72
# starting recursion on successor index 73
# 4 successors found for gen 4 precursor BTM00026
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 73
# starting recursion on successor index 74
# 4 successors found for gen 4 precursor BTM00049
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 74
# starting recursion on successor index 317
# No successors for gen 4 precursor BTM00139, moving to next gen 1 precursor.
# recursion complete for successor index 317
# starting recursion on successor index 318
# No successors for gen 4 precursor BTM00139, moving to next gen 1 precursor.
# recursion complete for successor index 318
# starting recursion on successor index 319
# No successors for gen 4 precursor BTM00140, moving to next gen 1 precursor.
# recursion complete for successor index 319
# starting recursion on successor index 320
# No successors for gen 4 precursor BTM00141, moving to next gen 1 precursor.
# recursion complete for successor index 320
# recursion complete for successor index 6
# starting recursion on successor index 7
# 21 successors found for gen 3 precursor BTM00007
# dict added to out_list for index 0
# starting recursion on successor index 75
# 4 successors found for gen 4 precursor BTM00027
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 75
# starting recursion on successor index 76
# 4 successors found for gen 4 precursor BTM00035
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 76
# starting recursion on successor index 77
# 4 successors found for gen 4 precursor BTM00027
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 77
# starting recursion on successor index 78
# 3 successors found for gen 4 precursor BTM00042
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 78
# starting recursion on successor index 79
# 3 successors found for gen 4 precursor BTM00042
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 79
# starting recursion on successor index 80
# 8 successors found for gen 4 precursor BTM00043
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 80
# starting recursion on successor index 81
# 5 successors found for gen 4 precursor BTM00050
# dict added to out_list for index 0
# starting recursion on successor index 456
# No successors for gen 5 precursor BTM00263, moving to next gen 1 precursor.
# recursion complete for successor index 456
# starting recursion on successor index 457
# No successors for gen 5 precursor BTM00263, moving to next gen 1 precursor.
# recursion complete for successor index 457
# starting recursion on successor index 458
# No successors for gen 5 precursor BTM00264, moving to next gen 1 precursor.
# recursion complete for successor index 458
# starting recursion on successor index 459
# No successors for gen 5 precursor BTM00265, moving to next gen 1 precursor.
# recursion complete for successor index 459
# starting recursion on successor index 460
# No successors for gen 5 precursor BTM00266, moving to next gen 1 precursor.
# recursion complete for successor index 460
# recursion complete for successor index 81
# starting recursion on successor index 82
# 5 successors found for gen 4 precursor BTM00051
# dict added to out_list for index 0
# starting recursion on successor index 461
# No successors for gen 5 precursor BTM00267, moving to next gen 1 precursor.
# recursion complete for successor index 461
# starting recursion on successor index 462
# No successors for gen 5 precursor BTM00267, moving to next gen 1 precursor.
# recursion complete for successor index 462
# starting recursion on successor index 463
# No successors for gen 5 precursor BTM00268, moving to next gen 1 precursor.
# recursion complete for successor index 463
# starting recursion on successor index 464
# No successors for gen 5 precursor BTM00269, moving to next gen 1 precursor.
# recursion complete for successor index 464
# starting recursion on successor index 465
# No successors for gen 5 precursor BTM00270, moving to next gen 1 precursor.
# recursion complete for successor index 465
# recursion complete for successor index 82
# starting recursion on successor index 83
# 4 successors found for gen 4 precursor BTM00052
# dict added to out_list for index 0
# starting recursion on successor index 466
# No successors for gen 5 precursor BTM00271, moving to next gen 1 precursor.
# recursion complete for successor index 466
# starting recursion on successor index 467
# No successors for gen 5 precursor BTM00271, moving to next gen 1 precursor.
# recursion complete for successor index 467
# starting recursion on successor index 468
# No successors for gen 5 precursor BTM00272, moving to next gen 1 precursor.
# recursion complete for successor index 468
# starting recursion on successor index 469
# No successors for gen 5 precursor BTM00273, moving to next gen 1 precursor.
# recursion complete for successor index 469
# recursion complete for successor index 83
# starting recursion on successor index 84
# 4 successors found for gen 4 precursor BTM00053
# dict added to out_list for index 0
# starting recursion on successor index 470
# No successors for gen 5 precursor BTM00274, moving to next gen 1 precursor.
# recursion complete for successor index 470
# starting recursion on successor index 471
# No successors for gen 5 precursor BTM00274, moving to next gen 1 precursor.
# recursion complete for successor index 471
# starting recursion on successor index 472
# No successors for gen 5 precursor BTM00275, moving to next gen 1 precursor.
# recursion complete for successor index 472
# starting recursion on successor index 473
# No successors for gen 5 precursor BTM00276, moving to next gen 1 precursor.
# recursion complete for successor index 473
# recursion complete for successor index 84
# starting recursion on successor index 85
# 8 successors found for gen 4 precursor BTM00043
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 85
# starting recursion on successor index 86
# 3 successors found for gen 4 precursor BTM00054
# dict added to out_list for index 0
# starting recursion on successor index 474
# No successors for gen 5 precursor BTM00277, moving to next gen 1 precursor.
# recursion complete for successor index 474
# starting recursion on successor index 475
# No successors for gen 5 precursor BTM00278, moving to next gen 1 precursor.
# recursion complete for successor index 475
# starting recursion on successor index 476
# No successors for gen 5 precursor BTM00279, moving to next gen 1 precursor.
# recursion complete for successor index 476
# recursion complete for successor index 86
# starting recursion on successor index 87
# 4 successors found for gen 4 precursor BTM00027
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 87
# starting recursion on successor index 88
# 4 successors found for gen 4 precursor BTM00035
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 88
# starting recursion on successor index 89
# 4 successors found for gen 4 precursor BTM00055
# dict added to out_list for index 0
# starting recursion on successor index 477
# No successors for gen 5 precursor BTM00280, moving to next gen 1 precursor.
# recursion complete for successor index 477
# starting recursion on successor index 478
# No successors for gen 5 precursor BTM00280, moving to next gen 1 precursor.
# recursion complete for successor index 478
# starting recursion on successor index 479
# No successors for gen 5 precursor BTM00281, moving to next gen 1 precursor.
# recursion complete for successor index 479
# starting recursion on successor index 480
# No successors for gen 5 precursor BTM00282, moving to next gen 1 precursor.
# recursion complete for successor index 480
# recursion complete for successor index 89
# starting recursion on successor index 90
# 4 successors found for gen 4 precursor BTM00027
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 90
# starting recursion on successor index 91
# 4 successors found for gen 4 precursor BTM00055
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 91
# starting recursion on successor index 321
# No successors for gen 4 precursor BTM00142, moving to next gen 1 precursor.
# recursion complete for successor index 321
# starting recursion on successor index 322
# No successors for gen 4 precursor BTM00142, moving to next gen 1 precursor.
# recursion complete for successor index 322
# starting recursion on successor index 323
# No successors for gen 4 precursor BTM00143, moving to next gen 1 precursor.
# recursion complete for successor index 323
# starting recursion on successor index 324
# No successors for gen 4 precursor BTM00144, moving to next gen 1 precursor.
# recursion complete for successor index 324
# recursion complete for successor index 7
# starting recursion on successor index 8
# 19 successors found for gen 3 precursor BTM00008
# dict added to out_list for index 0
# starting recursion on successor index 92
# 4 successors found for gen 4 precursor BTM00028
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 92
# starting recursion on successor index 93
# 5 successors found for gen 4 precursor BTM00036
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 93
# starting recursion on successor index 94
# 4 successors found for gen 4 precursor BTM00028
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 94
# starting recursion on successor index 95
# 5 successors found for gen 4 precursor BTM00044
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 95
# starting recursion on successor index 96
# 5 successors found for gen 4 precursor BTM00050
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 96
# starting recursion on successor index 97
# 1 successors found for gen 4 precursor BTM00056
# dict added to out_list for index 0
# starting recursion on successor index 481
# No successors for gen 5 precursor BTM00283, moving to next gen 1 precursor.
# recursion complete for successor index 481
# recursion complete for successor index 97
# starting recursion on successor index 98
# 5 successors found for gen 4 precursor BTM00057
# dict added to out_list for index 0
# starting recursion on successor index 482
# No successors for gen 5 precursor BTM00284, moving to next gen 1 precursor.
# recursion complete for successor index 482
# starting recursion on successor index 483
# No successors for gen 5 precursor BTM00285, moving to next gen 1 precursor.
# recursion complete for successor index 483
# starting recursion on successor index 484
# No successors for gen 5 precursor BTM00286, moving to next gen 1 precursor.
# recursion complete for successor index 484
# starting recursion on successor index 485
# No successors for gen 5 precursor BTM00287, moving to next gen 1 precursor.
# recursion complete for successor index 485
# starting recursion on successor index 486
# No successors for gen 5 precursor BTM00288, moving to next gen 1 precursor.
# recursion complete for successor index 486
# recursion complete for successor index 98
# starting recursion on successor index 99
# 3 successors found for gen 4 precursor BTM00058
# dict added to out_list for index 0
# starting recursion on successor index 487
# No successors for gen 5 precursor BTM00289, moving to next gen 1 precursor.
# recursion complete for successor index 487
# starting recursion on successor index 488
# No successors for gen 5 precursor BTM00290, moving to next gen 1 precursor.
# recursion complete for successor index 488
# starting recursion on successor index 489
# No successors for gen 5 precursor BTM00291, moving to next gen 1 precursor.
# recursion complete for successor index 489
# recursion complete for successor index 99
# starting recursion on successor index 100
# 3 successors found for gen 4 precursor BTM00059
# dict added to out_list for index 0
# starting recursion on successor index 490
# No successors for gen 5 precursor BTM00292, moving to next gen 1 precursor.
# recursion complete for successor index 490
# starting recursion on successor index 491
# No successors for gen 5 precursor BTM00293, moving to next gen 1 precursor.
# recursion complete for successor index 491
# starting recursion on successor index 492
# No successors for gen 5 precursor BTM00294, moving to next gen 1 precursor.
# recursion complete for successor index 492
# recursion complete for successor index 100
# starting recursion on successor index 101
# 3 successors found for gen 4 precursor BTM00060
# dict added to out_list for index 0
# starting recursion on successor index 493
# No successors for gen 5 precursor BTM00295, moving to next gen 1 precursor.
# recursion complete for successor index 493
# starting recursion on successor index 494
# No successors for gen 5 precursor BTM00296, moving to next gen 1 precursor.
# recursion complete for successor index 494
# starting recursion on successor index 495
# No successors for gen 5 precursor BTM00297, moving to next gen 1 precursor.
# recursion complete for successor index 495
# recursion complete for successor index 101
# starting recursion on successor index 102
# 5 successors found for gen 4 precursor BTM00061
# dict added to out_list for index 0
# starting recursion on successor index 496
# No successors for gen 5 precursor BTM00298, moving to next gen 1 precursor.
# recursion complete for successor index 496
# starting recursion on successor index 497
# No successors for gen 5 precursor BTM00299, moving to next gen 1 precursor.
# recursion complete for successor index 497
# starting recursion on successor index 498
# No successors for gen 5 precursor BTM00300, moving to next gen 1 precursor.
# recursion complete for successor index 498
# starting recursion on successor index 499
# No successors for gen 5 precursor BTM00301, moving to next gen 1 precursor.
# recursion complete for successor index 499
# starting recursion on successor index 500
# No successors for gen 5 precursor BTM00302, moving to next gen 1 precursor.
# recursion complete for successor index 500
# recursion complete for successor index 102
# starting recursion on successor index 103
# 4 successors found for gen 4 precursor BTM00028
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 103
# starting recursion on successor index 104
# 5 successors found for gen 4 precursor BTM00036
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 104
# starting recursion on successor index 105
# 4 successors found for gen 4 precursor BTM00028
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 105
# starting recursion on successor index 106
# 4 successors found for gen 4 precursor BTM00062
# dict added to out_list for index 0
# starting recursion on successor index 501
# No successors for gen 5 precursor BTM00303, moving to next gen 1 precursor.
# recursion complete for successor index 501
# starting recursion on successor index 502
# No successors for gen 5 precursor BTM00304, moving to next gen 1 precursor.
# recursion complete for successor index 502
# starting recursion on successor index 503
# No successors for gen 5 precursor BTM00305, moving to next gen 1 precursor.
# recursion complete for successor index 503
# starting recursion on successor index 504
# No successors for gen 5 precursor BTM00306, moving to next gen 1 precursor.
# recursion complete for successor index 504
# recursion complete for successor index 106
# starting recursion on successor index 107
# 4 successors found for gen 4 precursor BTM00062
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 107
# starting recursion on successor index 325
# No successors for gen 4 precursor BTM00145, moving to next gen 1 precursor.
# recursion complete for successor index 325
# starting recursion on successor index 326
# No successors for gen 4 precursor BTM00146, moving to next gen 1 precursor.
# recursion complete for successor index 326
# starting recursion on successor index 327
# No successors for gen 4 precursor BTM00147, moving to next gen 1 precursor.
# recursion complete for successor index 327
# recursion complete for successor index 8
# starting recursion on successor index 9
# 15 successors found for gen 3 precursor BTM00009
# dict added to out_list for index 0
# starting recursion on successor index 108
# 5 successors found for gen 4 precursor BTM00037
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 108
# starting recursion on successor index 109
# 4 successors found for gen 4 precursor BTM00029
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 109
# starting recursion on successor index 110
# 5 successors found for gen 4 precursor BTM00045
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 110
# starting recursion on successor index 111
# 5 successors found for gen 4 precursor BTM00051
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 111
# starting recursion on successor index 112
# 1 successors found for gen 4 precursor BTM00063
# dict added to out_list for index 0
# starting recursion on successor index 505
# No successors for gen 5 precursor BTM00307, moving to next gen 1 precursor.
# recursion complete for successor index 505
# recursion complete for successor index 112
# starting recursion on successor index 113
# 5 successors found for gen 4 precursor BTM00057
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 113
# starting recursion on successor index 114
# 3 successors found for gen 4 precursor BTM00064
# dict added to out_list for index 0
# starting recursion on successor index 506
# No successors for gen 5 precursor BTM00308, moving to next gen 1 precursor.
# recursion complete for successor index 506
# starting recursion on successor index 507
# No successors for gen 5 precursor BTM00309, moving to next gen 1 precursor.
# recursion complete for successor index 507
# starting recursion on successor index 508
# No successors for gen 5 precursor BTM00310, moving to next gen 1 precursor.
# recursion complete for successor index 508
# recursion complete for successor index 114
# starting recursion on successor index 115
# 5 successors found for gen 4 precursor BTM00065
# dict added to out_list for index 0
# starting recursion on successor index 509
# No successors for gen 5 precursor BTM00311, moving to next gen 1 precursor.
# recursion complete for successor index 509
# starting recursion on successor index 510
# No successors for gen 5 precursor BTM00312, moving to next gen 1 precursor.
# recursion complete for successor index 510
# starting recursion on successor index 511
# No successors for gen 5 precursor BTM00313, moving to next gen 1 precursor.
# recursion complete for successor index 511
# starting recursion on successor index 512
# No successors for gen 5 precursor BTM00314, moving to next gen 1 precursor.
# recursion complete for successor index 512
# starting recursion on successor index 513
# No successors for gen 5 precursor BTM00315, moving to next gen 1 precursor.
# recursion complete for successor index 513
# recursion complete for successor index 115
# starting recursion on successor index 116
# 4 successors found for gen 4 precursor BTM00029
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 116
# starting recursion on successor index 117
# 5 successors found for gen 4 precursor BTM00037
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 117
# starting recursion on successor index 118
# 4 successors found for gen 4 precursor BTM00066
# dict added to out_list for index 0
# starting recursion on successor index 514
# No successors for gen 5 precursor BTM00316, moving to next gen 1 precursor.
# recursion complete for successor index 514
# starting recursion on successor index 515
# No successors for gen 5 precursor BTM00317, moving to next gen 1 precursor.
# recursion complete for successor index 515
# starting recursion on successor index 516
# No successors for gen 5 precursor BTM00318, moving to next gen 1 precursor.
# recursion complete for successor index 516
# starting recursion on successor index 517
# No successors for gen 5 precursor BTM00319, moving to next gen 1 precursor.
# recursion complete for successor index 517
# recursion complete for successor index 118
# starting recursion on successor index 119
# 4 successors found for gen 4 precursor BTM00066
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 119
# starting recursion on successor index 328
# No successors for gen 4 precursor BTM00148, moving to next gen 1 precursor.
# recursion complete for successor index 328
# starting recursion on successor index 329
# No successors for gen 4 precursor BTM00149, moving to next gen 1 precursor.
# recursion complete for successor index 329
# starting recursion on successor index 330
# No successors for gen 4 precursor BTM00150, moving to next gen 1 precursor.
# recursion complete for successor index 330
# recursion complete for successor index 9
# starting recursion on successor index 10
# 14 successors found for gen 3 precursor BTM00010
# dict added to out_list for index 0
# starting recursion on successor index 120
# 3 successors found for gen 4 precursor BTM00059
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 120
# starting recursion on successor index 121
# 2 successors found for gen 4 precursor BTM00030
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 121
# starting recursion on successor index 122
# 3 successors found for gen 4 precursor BTM00038
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 122
# starting recursion on successor index 123
# 2 successors found for gen 4 precursor BTM00030
# Precursor-successor relationship already recorded, skipping to next precursor.
# recursion complete for successor index 123
# starting recursion on successor index 124
# 4 successors found for gen 4 precursor BTM00046
# ...
#        'chem_name': None}}]},
#    {'precursor': {'smiles': 'CC(C)(CC=1C2C(C(=CC1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O2)O',
#      'inchikey': None,
#      'casrn': None,
#      'hcd_smiles': None,
#      'dtxsid': None,
#      'chem_name': None},
#     'successors': [{'enzyme': ['EC 2.4.1.17'],
#       'mechanism': 'Alkyl-OH-glucuronidation',
#       'generation': 4,
#       'metabolite': {'smiles': 'CC(C)(CC=1C2C(C(=CC1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O2)OC3OC(C(O)=O)C(C(C3O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['EC 2.5.1.18'],
#       'mechanism': 'GSH-conjugation of epoxide',
#       'generation': 4,
#       'metabolite': {'smiles': 'CC(C)(CC=1C(C(C(=CC1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)SCC(NC(=O)CCC(N)C(=O)O)C(=O)NCC(=O)O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['EC 2.5.1.18'],
#       'mechanism': 'GSH-conjugation of epoxide',
#       'generation': 4,
#       'metabolite': {'smiles': 'CC(C)(CC=1C(C(C(=CC1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)SCC(NC(=O)CCC(N)C(=O)O)C(=O)NCC(=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}}]},
#    {'precursor': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O',
#      'inchikey': None,
#      'casrn': None,
#      'hcd_smiles': None,
#      'dtxsid': None,
#      'chem_name': None},
#     'successors': [{'enzyme': ['CYP1A2',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6'],
#       'mechanism': 'Hydroxylation of penultimate aliphatic carbon adjacent to aromatic carbon',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(C)(C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C9', 'CYP2C19'],
#       'mechanism': 'Oxidation of secondary alcohol to ketone',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)=O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C8', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of non-terminal aliphatic carbon adjacent to aromatic ring',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)C(C1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C8', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of non-terminal aliphatic carbon adjacent to aromatic ring',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(C)(C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C8', 'CYP2C9', 'CYP2C19', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of benzene on carbon ortho to electron donating group',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=C(C=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C8', 'CYP2C9', 'CYP2C19', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of benzene on carbon ortho to electron donating group',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C(=C1)O)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2A6',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6',
#        'CYP2E1',
#        'CYP3A4'],
#       'mechanism': 'Hydroxylation of terminal methyl',
#       'generation': 3,
#       'metabolite': {'smiles': 'C(C(C)CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2A6',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6',
#        'CYP2E1',
#        'CYP3A4'],
#       'mechanism': 'Hydroxylation of terminal methyl',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(CO)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2A6', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Terminal desaturation',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(=C)CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2A6', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Terminal desaturation',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(=C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2E1',
#        'CYP3A4'],
#       'mechanism': 'Epoxidation of arene',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC=1C2C(C(=CC1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O2',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2A6',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6',
#        'CYP3A4'],
#       'mechanism': 'alpha-Hydroxylation of carbonyl group',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(C)(C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2B6', 'CYP2C19', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Allylic hydroxylation',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)C(C1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP2A6', 'CYP2B6', 'CYP2C8', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of penultimate aliphatic tertiary carbon',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP2A6', 'CYP2B6', 'CYP2C8', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of penultimate aliphatic tertiary carbon',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(C)(C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP2A6', 'CYP2B6', 'CYP2C8', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of alkyl methine',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['EC 2.4.1.17'],
#       'mechanism': 'Alkyl-OH-glucuronidation',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)OC2OC(C(O)=O)C(C(C2O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['EC 2.8.2.2'],
#       'mechanism': 'Sulfation of secondary alcohol',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)OS(O)(=O)=O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}}]},
#    {'precursor': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#      'inchikey': None,
#      'casrn': None,
#      'hcd_smiles': None,
#      'dtxsid': None,
#      'chem_name': None},
#     'successors': [{'enzyme': ['EC 2.4.1.17'],
#       'mechanism': 'Alkyl-OH-glucuronidation',
#       'generation': 4,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)OC2OC(C(O)=O)C(C(C2O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['EC 2.4.1.17'],
#       'mechanism': 'Alkyl-OH-glucuronidation',
#       'generation': 4,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)OC2OC(C(O)=O)C(C(C2O)O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['EC 2.8.2.2'],
#       'mechanism': 'Sulfation of secondary alcohol',
#       'generation': 4,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)OS(O)(=O)=O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}}]},
#    {'precursor': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O',
#      'inchikey': None,
#      'casrn': None,
#      'hcd_smiles': None,
#      'dtxsid': None,
#      'chem_name': None},
#     'successors': [{'enzyme': ['CYP1A2',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6'],
#       'mechanism': 'Hydroxylation of penultimate aliphatic carbon adjacent to aromatic carbon',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)(C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C8', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of non-terminal aliphatic carbon adjacent to aromatic ring',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(C(C1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C8', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of non-terminal aliphatic carbon adjacent to aromatic ring',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)(C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C8', 'CYP2C9', 'CYP2C19', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of benzene on carbon ortho to electron donating group',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=C(C=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2C8', 'CYP2C9', 'CYP2C19', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of benzene on carbon ortho to electron donating group',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C(=C1)O)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2A6',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6',
#        'CYP2E1',
#        'CYP3A4'],
#       'mechanism': 'Hydroxylation of terminal methyl',
#       'generation': 3,
#       'metabolite': {'smiles': 'C(C(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2A6',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6',
#        'CYP2E1',
#        'CYP3A4'],
#       'mechanism': 'Hydroxylation of terminal methyl',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(CO)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2A6', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Terminal desaturation',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(=C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2E1',
#        'CYP3A4'],
#       'mechanism': 'Epoxidation of arene',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC=1C2C(C(=CC1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O2)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2A6',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6',
#        'CYP3A4'],
#       'mechanism': 'alpha-Hydroxylation of carbonyl group',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)(C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2',
#        'CYP2A6',
#        'CYP2B6',
#        'CYP2C8',
#        'CYP2C9',
#        'CYP2C19',
#        'CYP2D6',
#        'CYP3A4'],
#       'mechanism': 'alpha-Hydroxylation of carbonyl group',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)C(C([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP1A2', 'CYP2B6', 'CYP2C19', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Allylic hydroxylation',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(C(C1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['CYP2A6', 'CYP2B6', 'CYP2C8', 'CYP2C9', 'CYP2D6', 'CYP3A4'],
#       'mechanism': 'Hydroxylation of penultimate aliphatic tertiary carbon',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)(C(=O)OC(C[N+](C)(C)C)CC([O-])=O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}},
#      {'enzyme': ['EC 2.4.1.17'],
#       'mechanism': 'Alkyl-OH-glucuronidation',
#       'generation': 3,
#       'metabolite': {'smiles': 'CC(C)(CC1=CC=C(C=C1)C(C)C(=O)OC(C[N+](C)(C)C)CC([O-])=O)OC2OC(C(O)=O)C(C(C2O)O)O',
#        'inchikey': None,
#        'casrn': None,
#        'hcd_smiles': None,
#        'dtxsid': None,
#        'chem_name': None}}]}]},
#  '/home/jovyan/work/bt_tmpfiles/btrans_out_DTXSID3047138_ud0k9966.csv')
